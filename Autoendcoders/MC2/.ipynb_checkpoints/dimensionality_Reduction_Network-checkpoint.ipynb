# %%
#Importing the Libraries
from sklearn.datasets import make_classification
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import load_model
import math
import pandas as pd
import tensorflow as tf
from tensorflow.keras.utils import plot_model

# %%
TRAIN_DATA_PATH = 'NASA/MC2.csv'

data = pd.read_csv(TRAIN_DATA_PATH)
nameOfHeadersWithLable = data.columns.values
display(data)
# Out:
#      LOC_BLA0K  BRA0CH_COU0T  CALL_PAIRS  LOC_CODE_A0D_COMME0T  LOC_COMME0TS  \
# 0            2             3           0                     2             7
# 1            1             3           1                     1             0
# 2            6             5           1                     4             5
# 3            6             5           1                     4             3
# 4            2             3           0                     0             1
# ..         ...           ...         ...                   ...           ...
# 120         14            24           8                     0            14
# 121         26            31           7                     9            21
# 122         19            13           3                    11            19
# 123          5             3           3                     7             3
# 124         23            15           3                    10            27
#
#      CO0DITIO0_COU0T  C1CLOMATIC_COMPLEXIT1  C1CLOMATIC_DE0SIT1  \
# 0                  4                      2                0.18
# 1                  4                      2                0.13
# 2                  8                      3                0.20
# 3                  8                      3                0.20
# 4                  4                      2                0.29
# ..               ...                    ...                 ...
# 120               30                     15                0.25
# 121               60                     16                0.18
# 122               24                      7                0.10
# 123                4                      2                0.08
# 124               28                      8                0.09
#
#      DECISIO0_COU0T  DECISIO0_DE0SIT1  ...  0ODE_COU0T  \
# 0                 2              2.00  ...           6
# 1                 2              2.00  ...           7
# 2                 4              2.00  ...          10
# 3                 4              2.00  ...          10
# 4                 2              2.00  ...           6
# ..              ...               ...  ...         ...
# 120              14              2.14  ...          36
# 121              30              2.00  ...          69
# 122              12              2.00  ...          30
# 123               2              2.00  ...          10
# 124              14              2.00  ...          33
#
#      0ORMALIZED_C1LOMATIC_COMPLEXIT1  0UM_OPERA0DS  0UM_OPERATORS  \
# 0                               0.09            11             15
# 1                               0.11            12             19
# 2                               0.10            25             38
# 3                               0.12            26             38
# 4                               0.17             7             13
# ..                               ...           ...            ...
# 120                             0.17            62            100
# 121                             0.12           241            237
# 122                             0.06           215            224
# 123                             0.06            77             82
# 124                             0.06           268            274
#
#      0UM_U0IQUE_OPERA0DS  0UM_U0IQUE_OPERATORS  0UMBER_OF_LI0ES  \
# 0                      6                     8               22
# 1                      8                    10               18
# 2                     12                    11               29
# 3                     10                    11               26
# 4                      5                     9               12
# ..                   ...                   ...              ...
# 120                   41                    28               89
# 121                   64                    19              136
# 122                   73                    17              108
# 123                   36                    12               35
# 124                   98                    20              137
#
#      PERCE0T_COMME0TS  LOC_TOTAL  Defective
# 0               50.00         11          0
# 1                6.67         15          0
# 2               45.00         15          0
# 3               38.89         15          0
# 4               12.50          7          0
# ..                ...        ...        ...
# 120             19.18         59          1
# 121             27.78         87          1
# 122             34.48         68          0
# 123             35.71         25          0
# 124             33.04         85          0
#
# [125 rows x 40 columns]

# %%
# transform data
scaler = MinMaxScaler()
scaled = scaler.fit_transform(data)
reduced_df = pd.DataFrame(scaled, columns=nameOfHeadersWithLable)
reduced_df.to_csv('FirstlyScaledData.csv')
# display(reduced_df)
# display(scaled)

data2 = pd.read_csv('FirstlyScaledData.csv')
y = data2.Defective
X = data2.drop('Defective', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2)

nameOfHeaders = X_train.columns.values

# %%
# AutoEncoder Model Preparation
n_inputs = X.shape[1]
# define encoder
input_data_shape= Input(shape=(n_inputs,))
# encoder level 1
encoder= Dense(n_inputs*2)(input_data_shape)
encoder = BatchNormalization()(encoder)
encoder= LeakyReLU()(encoder)
# encoder level 2
encoder= Dense(n_inputs)(encoder)
encoder= BatchNormalization()(encoder)
encoder= LeakyReLU()(encoder)
# bottleneck
n_bottleneck = round(float(n_inputs) / 2.0)
bottleneck = Dense(n_bottleneck)(encoder)
# define decoder, level 1
decoder = Dense(n_inputs)(bottleneck)
decoder = BatchNormalization()(decoder)
decoder = LeakyReLU()(decoder)
# decoder level 2
decoder = Dense(n_inputs*2)(decoder)
decoder = BatchNormalization()(decoder)
decoder = LeakyReLU()(decoder)

# %%
# output layer
output = Dense(n_inputs, activation='linear')(decoder)
# define autoencoder model
model = Model(inputs=input_data_shape, outputs=output)
# compile autoencoder model
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 40)]              0
#
#  dense (Dense)               (None, 80)                3280
#
#  batch_normalization (BatchN  (None, 80)               320
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 80)                0
#
#  dense_1 (Dense)             (None, 40)                3240
#
#  batch_normalization_1 (Batc  (None, 40)               160
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 40)                0
#
#  dense_2 (Dense)             (None, 20)                820
#
#  dense_3 (Dense)             (None, 40)                840
#
#  batch_normalization_2 (Batc  (None, 40)               160
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 40)                0
#
#  dense_4 (Dense)             (None, 80)                3280
#
#  batch_normalization_3 (Batc  (None, 80)               320
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 80)                0
#
#  dense_5 (Dense)             (None, 40)                3240
#
# =================================================================
# Total params: 15,660
# Trainable params: 15,180
# Non-trainable params: 480
# _________________________________________________________________

# %%
# compile autoencoder model
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
# plot the autoencoder
plot_model(model, 'autoencoder_compress.png', show_shapes=True)
# fit the autoencoder model to reconstruct input
history = model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=2, validation_data=(X_test,y_test))
# # plot loss
# pyplot.plot(history.history['loss'], label='train')
# pyplot.plot(history.history['val_loss'], label='test')
# pyplot.legend()
# pyplot.show()
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
# Epoch 1/50
# 7/7 - 2s - loss: 0.8424 - accuracy: 0.0800 - val_loss: 3.0030 - val_accuracy: 0.0000e+00 - 2s/epoch - 262ms/step
# Epoch 2/50
# 7/7 - 0s - loss: 0.5041 - accuracy: 0.0500 - val_loss: 1.8092 - val_accuracy: 0.0000e+00 - 58ms/epoch - 8ms/step
# Epoch 3/50
# 7/7 - 0s - loss: 0.3598 - accuracy: 0.0500 - val_loss: 1.5072 - val_accuracy: 0.0000e+00 - 56ms/epoch - 8ms/step
# Epoch 4/50
# 7/7 - 0s - loss: 0.2953 - accuracy: 0.0500 - val_loss: 1.2759 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 5/50
# 7/7 - 0s - loss: 0.2516 - accuracy: 0.0100 - val_loss: 1.1273 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 6/50
# 7/7 - 0s - loss: 0.2278 - accuracy: 0.0100 - val_loss: 0.9712 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 7/50
# 7/7 - 0s - loss: 0.2106 - accuracy: 0.0100 - val_loss: 0.8852 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 8/50
# 7/7 - 0s - loss: 0.2005 - accuracy: 0.0100 - val_loss: 0.7628 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 9/50
# 7/7 - 0s - loss: 0.1784 - accuracy: 0.0100 - val_loss: 0.6472 - val_accuracy: 0.0000e+00 - 56ms/epoch - 8ms/step
# Epoch 10/50
# 7/7 - 0s - loss: 0.1920 - accuracy: 0.0000e+00 - val_loss: 0.5585 - val_accuracy: 0.0000e+00 - 64ms/epoch - 9ms/step
# Epoch 11/50
# 7/7 - 0s - loss: 0.1738 - accuracy: 0.0100 - val_loss: 0.5124 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 12/50
# 7/7 - 0s - loss: 0.1509 - accuracy: 0.0300 - val_loss: 0.4962 - val_accuracy: 0.0000e+00 - 56ms/epoch - 8ms/step
# Epoch 13/50
# 7/7 - 0s - loss: 0.1419 - accuracy: 0.0300 - val_loss: 0.4402 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 14/50
# 7/7 - 0s - loss: 0.1602 - accuracy: 0.0200 - val_loss: 0.4232 - val_accuracy: 0.0000e+00 - 43ms/epoch - 6ms/step
# Epoch 15/50
# 7/7 - 0s - loss: 0.1540 - accuracy: 0.0700 - val_loss: 0.4329 - val_accuracy: 0.0000e+00 - 50ms/epoch - 7ms/step
# Epoch 16/50
# 7/7 - 0s - loss: 0.1457 - accuracy: 0.0200 - val_loss: 0.4197 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 17/50
# 7/7 - 0s - loss: 0.1487 - accuracy: 0.0200 - val_loss: 0.4215 - val_accuracy: 0.0000e+00 - 56ms/epoch - 8ms/step
# Epoch 18/50
# 7/7 - 0s - loss: 0.1832 - accuracy: 0.0200 - val_loss: 0.3611 - val_accuracy: 0.0000e+00 - 56ms/epoch - 8ms/step
# Epoch 19/50
# 7/7 - 0s - loss: 0.1654 - accuracy: 0.0100 - val_loss: 0.3552 - val_accuracy: 0.0000e+00 - 40ms/epoch - 6ms/step
# Epoch 20/50
# 7/7 - 0s - loss: 0.1688 - accuracy: 0.0000e+00 - val_loss: 0.3860 - val_accuracy: 0.0000e+00 - 40ms/epoch - 6ms/step
# Epoch 21/50
# 7/7 - 0s - loss: 0.1471 - accuracy: 0.0100 - val_loss: 0.3512 - val_accuracy: 0.0000e+00 - 46ms/epoch - 7ms/step
# Epoch 22/50
# 7/7 - 0s - loss: 0.1563 - accuracy: 0.0400 - val_loss: 0.3234 - val_accuracy: 0.0000e+00 - 49ms/epoch - 7ms/step
# Epoch 23/50
# 7/7 - 0s - loss: 0.1433 - accuracy: 0.0100 - val_loss: 0.3240 - val_accuracy: 0.0000e+00 - 50ms/epoch - 7ms/step
# Epoch 24/50
# 7/7 - 0s - loss: 0.1335 - accuracy: 0.0300 - val_loss: 0.3145 - val_accuracy: 0.0000e+00 - 56ms/epoch - 8ms/step
# Epoch 25/50
# 7/7 - 0s - loss: 0.1344 - accuracy: 0.0300 - val_loss: 0.2942 - val_accuracy: 0.0000e+00 - 40ms/epoch - 6ms/step
# Epoch 26/50
# 7/7 - 0s - loss: 0.1410 - accuracy: 0.0300 - val_loss: 0.2774 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 27/50
# 7/7 - 0s - loss: 0.1173 - accuracy: 0.0100 - val_loss: 0.3154 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 28/50
# 7/7 - 0s - loss: 0.1584 - accuracy: 0.0300 - val_loss: 0.3648 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 29/50
# 7/7 - 0s - loss: 0.1534 - accuracy: 0.0400 - val_loss: 0.3069 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 30/50
# 7/7 - 0s - loss: 0.1248 - accuracy: 0.0100 - val_loss: 0.3091 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 31/50
# 7/7 - 0s - loss: 0.1185 - accuracy: 0.0100 - val_loss: 0.3593 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 32/50
# 7/7 - 0s - loss: 0.1317 - accuracy: 0.0100 - val_loss: 0.3240 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 33/50
# 7/7 - 0s - loss: 0.1037 - accuracy: 0.0400 - val_loss: 0.3656 - val_accuracy: 0.0000e+00 - 44ms/epoch - 6ms/step
# Epoch 34/50
# 7/7 - 0s - loss: 0.0963 - accuracy: 0.0100 - val_loss: 0.3225 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 35/50
# 7/7 - 0s - loss: 0.1113 - accuracy: 0.0100 - val_loss: 0.2674 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 36/50
# 7/7 - 0s - loss: 0.1177 - accuracy: 0.0200 - val_loss: 0.3077 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 37/50
# 7/7 - 0s - loss: 0.1352 - accuracy: 0.0200 - val_loss: 0.3553 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 38/50
# 7/7 - 0s - loss: 0.1125 - accuracy: 0.0300 - val_loss: 0.4029 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 39/50
# 7/7 - 0s - loss: 0.1150 - accuracy: 0.0200 - val_loss: 0.4309 - val_accuracy: 0.0000e+00 - 40ms/epoch - 6ms/step
# Epoch 40/50
# 7/7 - 0s - loss: 0.1360 - accuracy: 0.0200 - val_loss: 0.5576 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 41/50
# 7/7 - 0s - loss: 0.1557 - accuracy: 0.0000e+00 - val_loss: 0.7862 - val_accuracy: 0.0000e+00 - 40ms/epoch - 6ms/step
# Epoch 42/50
# 7/7 - 0s - loss: 0.1163 - accuracy: 0.0000e+00 - val_loss: 0.6096 - val_accuracy: 0.0000e+00 - 41ms/epoch - 6ms/step
# Epoch 43/50
# 7/7 - 0s - loss: 0.1221 - accuracy: 0.0300 - val_loss: 0.5183 - val_accuracy: 0.0400 - 48ms/epoch - 7ms/step
# Epoch 44/50
# 7/7 - 0s - loss: 0.1182 - accuracy: 0.0000e+00 - val_loss: 0.3297 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 45/50
# 7/7 - 0s - loss: 0.1207 - accuracy: 0.0100 - val_loss: 0.2794 - val_accuracy: 0.0000e+00 - 40ms/epoch - 6ms/step
# Epoch 46/50
# 7/7 - 0s - loss: 0.1064 - accuracy: 0.0000e+00 - val_loss: 0.2717 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 47/50
# 7/7 - 0s - loss: 0.1165 - accuracy: 0.0000e+00 - val_loss: 0.2799 - val_accuracy: 0.0000e+00 - 42ms/epoch - 6ms/step
# Epoch 48/50
# 7/7 - 0s - loss: 0.1168 - accuracy: 0.0000e+00 - val_loss: 0.3627 - val_accuracy: 0.0000e+00 - 48ms/epoch - 7ms/step
# Epoch 49/50
# 7/7 - 0s - loss: 0.1098 - accuracy: 0.0000e+00 - val_loss: 0.4877 - val_accuracy: 0.0000e+00 - 56ms/epoch - 8ms/step
# Epoch 50/50
# 7/7 - 0s - loss: 0.1283 - accuracy: 0.0200 - val_loss: 0.3749 - val_accuracy: 0.0400 - 48ms/epoch - 7ms/step

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
plt.plot(range(50), acc, label='Training Accuracy')
plt.plot(range(50), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Figure (a) Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(50), loss, label='Training Loss')
plt.plot(range(50), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Figure (b) Training and Validation Loss')
plt.show()

# define an encoder model (without the decoder)
encoder = Model(inputs=input_data_shape, outputs=bottleneck)
# save the encoder to file
encoder.save('encoder.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
#Building a Base Model to compare the performance after compressing the data using Encoder model.

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
t = MinMaxScaler()
t.fit(X_train)
X_train = t.transform(X_train)
X_test = t.transform(X_test)
# define model
model = RandomForestClassifier()
# fit model on training set
model.fit(X_train, y_train)
# make prediction on test set
yhat = model.predict(X_test)
# calculate accuracy
acc = accuracy_score(y_test, yhat)
print(acc)
# Out:
# 0.52

# %%
#Compressing the input data using Encoder Model and fitting it on the Logistic Regression model.
# load the model from file
encoder = load_model('encoder.h5')

encoder.compile(optimizer='adam', loss='mse')

# encode the train data
X_train_encode = encoder.predict(X_train)

# encode the test data
X_test_encode = encoder.predict(X_test)

# nameOfHeaders = X_train.columns.values
# reduced_df = pd.DataFrame(encoder.predict(x_test), columns=nameOfHeaders)

# reduced_df.to_csv('PredictedJM1OnTestData.csv')


# define the model
random_forest = RandomForestClassifier(max_depth=50)
# fit the model on the training set
random_forest.fit(X_train_encode, y_train)
# make predictions on the test set
yhat = random_forest.predict(X_test_encode)
# calculate classification accuracy
acc = accuracy_score(y_test, yhat)
print(acc)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 4/4 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 0.64

# %%
print('Optimal number of features: {}'.format(random_forest.n_features_))
# Out:
# Optimal number of features: 20
# C:\Users\Zbook\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\utils\deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
display(random_forest.feature_importances_)
plt.figure(figsize=(16, 9))
plt.title('Random Forest with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('% Correct Classification', fontsize=14, labelpad=20)
plt.plot(range(1, len(random_forest.feature_importances_) + 1), random_forest.feature_importances_, color='#303F9F', linewidth=3)

plt.show()
# Out:
# array([0.02751948, 0.02990967, 0.05443362, 0.0308825 , 0.06084154,
#        0.09018339, 0.07655736, 0.03464487, 0.03513138, 0.03657906,
#        0.05410066, 0.03022363, 0.08075179, 0.09687528, 0.04385205,
#        0.04380966, 0.06206658, 0.03215282, 0.04678454, 0.03270011])
