# %%
#Importing the Libraries
from sklearn.datasets import make_classification
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import load_model
import math
import pandas as pd
import tensorflow as tf
from tensorflow.keras.utils import plot_model

# %%
TRAIN_DATA_PATH = 'NASA/PC5.csv'

data = pd.read_csv(TRAIN_DATA_PATH)
nameOfHeadersWithLable = data.columns.values

# %%
# transform data
scaler = MinMaxScaler()
scaled = scaler.fit_transform(data)
reduced_df = pd.DataFrame(scaled, columns=nameOfHeadersWithLable)
reduced_df.to_csv('FirstlyScaledData.csv')
# display(reduced_df)
# display(scaled)

data2 = pd.read_csv('FirstlyScaledData.csv')
y = data2.Defective
X = data2.drop('Defective', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2)

nameOfHeaders = X_train.columns.values

# %%
# AutoEncoder Model Preparation
n_inputs = X.shape[1]
# define encoder
input_data_shape= Input(shape=(n_inputs,))
# encoder level 1
encoder= Dense(n_inputs*2)(input_data_shape)
encoder = BatchNormalization()(encoder)
encoder= LeakyReLU()(encoder)
# encoder level 2
encoder= Dense(n_inputs)(encoder)
encoder= BatchNormalization()(encoder)
encoder= LeakyReLU()(encoder)
# bottleneck
n_bottleneck = round(float(n_inputs) / 2.0)
bottleneck = Dense(n_bottleneck)(encoder)
# define decoder, level 1
decoder = Dense(n_inputs)(bottleneck)
decoder = BatchNormalization()(decoder)
decoder = LeakyReLU()(decoder)
# decoder level 2
decoder = Dense(n_inputs*2)(decoder)
decoder = BatchNormalization()(decoder)
decoder = LeakyReLU()(decoder)

# %%
# output layer
output = Dense(n_inputs, activation='linear')(decoder)
# define autoencoder model
model = Model(inputs=input_data_shape, outputs=output)
# compile autoencoder model
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 39)]              0
#
#  dense (Dense)               (None, 78)                3120
#
#  batch_normalization (BatchN  (None, 78)               312
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 78)                0
#
#  dense_1 (Dense)             (None, 39)                3081
#
#  batch_normalization_1 (Batc  (None, 39)               156
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 39)                0
#
#  dense_2 (Dense)             (None, 20)                800
#
#  dense_3 (Dense)             (None, 39)                819
#
#  batch_normalization_2 (Batc  (None, 39)               156
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 39)                0
#
#  dense_4 (Dense)             (None, 78)                3120
#
#  batch_normalization_3 (Batc  (None, 78)               312
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 78)                0
#
#  dense_5 (Dense)             (None, 39)                3081
#
# =================================================================
# Total params: 14,957
# Trainable params: 14,489
# Non-trainable params: 468
# _________________________________________________________________

# %%
# compile autoencoder model
model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
# plot the autoencoder
plot_model(model, 'autoencoder_compress.png', show_shapes=True)
# fit the autoencoder model to reconstruct input
history = model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=2, validation_data=(X_test,y_test))
# # plot loss
# pyplot.plot(history.history['loss'], label='train')
# pyplot.plot(history.history['val_loss'], label='test')
# pyplot.legend()
# pyplot.show()
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
# Epoch 1/50
# 849/849 - 3s - loss: 0.0389 - accuracy: 0.0220 - val_loss: 0.0745 - val_accuracy: 0.0000e+00 - 3s/epoch - 4ms/step
# Epoch 2/50
# 849/849 - 2s - loss: 0.0298 - accuracy: 0.0259 - val_loss: 0.1107 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 3/50
# 849/849 - 2s - loss: 0.0294 - accuracy: 0.0119 - val_loss: 0.0667 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 4/50
# 849/849 - 2s - loss: 0.0281 - accuracy: 0.0155 - val_loss: 0.1153 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 5/50
# 849/849 - 2s - loss: 0.0269 - accuracy: 0.0325 - val_loss: 0.1066 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 6/50
# 849/849 - 2s - loss: 0.0252 - accuracy: 0.0223 - val_loss: 0.1516 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 7/50
# 849/849 - 2s - loss: 0.0244 - accuracy: 0.0149 - val_loss: 0.2077 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 8/50
# 849/849 - 2s - loss: 0.0241 - accuracy: 0.0169 - val_loss: 1.1427 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 9/50
# 849/849 - 2s - loss: 0.0236 - accuracy: 0.0101 - val_loss: 0.8310 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 10/50
# 849/849 - 2s - loss: 0.0229 - accuracy: 0.0147 - val_loss: 0.2219 - val_accuracy: 0.1494 - 2s/epoch - 2ms/step
# Epoch 11/50
# 849/849 - 2s - loss: 0.0227 - accuracy: 0.0144 - val_loss: 0.0942 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 12/50
# 849/849 - 2s - loss: 0.0229 - accuracy: 0.0156 - val_loss: 0.4431 - val_accuracy: 2.9472e-04 - 2s/epoch - 2ms/step
# Epoch 13/50
# 849/849 - 2s - loss: 0.0218 - accuracy: 0.0121 - val_loss: 0.0661 - val_accuracy: 0.0021 - 2s/epoch - 2ms/step
# Epoch 14/50
# 849/849 - 2s - loss: 0.0218 - accuracy: 0.0101 - val_loss: 6.9881 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 15/50
# 849/849 - 2s - loss: 0.0228 - accuracy: 0.0153 - val_loss: 0.4882 - val_accuracy: 0.0536 - 2s/epoch - 2ms/step
# Epoch 16/50
# 849/849 - 2s - loss: 0.0221 - accuracy: 0.0108 - val_loss: 0.0575 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 17/50
# 849/849 - 2s - loss: 0.0219 - accuracy: 0.0138 - val_loss: 0.1138 - val_accuracy: 0.0510 - 2s/epoch - 2ms/step
# Epoch 18/50
# 849/849 - 2s - loss: 0.0213 - accuracy: 0.0153 - val_loss: 0.1483 - val_accuracy: 0.0144 - 2s/epoch - 2ms/step
# Epoch 19/50
# 849/849 - 2s - loss: 0.0216 - accuracy: 0.0195 - val_loss: 0.0537 - val_accuracy: 8.8417e-04 - 2s/epoch - 2ms/step
# Epoch 20/50
# 849/849 - 2s - loss: 0.0215 - accuracy: 0.0179 - val_loss: 0.0997 - val_accuracy: 0.0029 - 2s/epoch - 2ms/step
# Epoch 21/50
# 849/849 - 2s - loss: 0.0210 - accuracy: 0.0102 - val_loss: 0.1804 - val_accuracy: 0.0083 - 2s/epoch - 2ms/step
# Epoch 22/50
# 849/849 - 2s - loss: 0.0217 - accuracy: 0.0060 - val_loss: 1.2673 - val_accuracy: 0.0027 - 2s/epoch - 2ms/step
# Epoch 23/50
# 849/849 - 2s - loss: 0.0216 - accuracy: 0.0042 - val_loss: 23.5520 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 24/50
# 849/849 - 2s - loss: 0.0223 - accuracy: 0.0047 - val_loss: 0.5642 - val_accuracy: 0.0041 - 2s/epoch - 2ms/step
# Epoch 25/50
# 849/849 - 2s - loss: 0.0214 - accuracy: 0.0031 - val_loss: 7.2013 - val_accuracy: 0.0236 - 2s/epoch - 2ms/step
# Epoch 26/50
# 849/849 - 2s - loss: 0.0212 - accuracy: 0.0062 - val_loss: 1.5001 - val_accuracy: 2.9472e-04 - 2s/epoch - 2ms/step
# Epoch 27/50
# 849/849 - 2s - loss: 0.0216 - accuracy: 0.0073 - val_loss: 0.2727 - val_accuracy: 0.0044 - 2s/epoch - 2ms/step
# Epoch 28/50
# 849/849 - 2s - loss: 0.0208 - accuracy: 0.0108 - val_loss: 0.1275 - val_accuracy: 0.0038 - 2s/epoch - 2ms/step
# Epoch 29/50
# 849/849 - 2s - loss: 0.0209 - accuracy: 0.0098 - val_loss: 1.7350 - val_accuracy: 5.8945e-04 - 2s/epoch - 2ms/step
# Epoch 30/50
# 849/849 - 2s - loss: 0.0211 - accuracy: 0.0156 - val_loss: 0.0740 - val_accuracy: 0.0018 - 2s/epoch - 2ms/step
# Epoch 31/50
# 849/849 - 2s - loss: 0.0210 - accuracy: 0.0124 - val_loss: 0.0582 - val_accuracy: 0.0065 - 2s/epoch - 2ms/step
# Epoch 32/50
# 849/849 - 2s - loss: 0.0202 - accuracy: 0.0087 - val_loss: 0.0338 - val_accuracy: 0.0068 - 2s/epoch - 2ms/step
# Epoch 33/50
# 849/849 - 2s - loss: 0.0204 - accuracy: 0.0144 - val_loss: 0.0411 - val_accuracy: 0.0035 - 2s/epoch - 2ms/step
# Epoch 34/50
# 849/849 - 2s - loss: 0.0207 - accuracy: 0.0141 - val_loss: 0.7045 - val_accuracy: 0.0012 - 2s/epoch - 2ms/step
# Epoch 35/50
# 849/849 - 2s - loss: 0.0208 - accuracy: 0.0192 - val_loss: 0.1070 - val_accuracy: 2.9472e-04 - 2s/epoch - 2ms/step
# Epoch 36/50
# 849/849 - 2s - loss: 0.0206 - accuracy: 0.0090 - val_loss: 0.5343 - val_accuracy: 0.0156 - 2s/epoch - 2ms/step
# Epoch 37/50
# 849/849 - 2s - loss: 0.0200 - accuracy: 0.0101 - val_loss: 0.0468 - val_accuracy: 0.0027 - 2s/epoch - 2ms/step
# Epoch 38/50
# 849/849 - 2s - loss: 0.0204 - accuracy: 0.0283 - val_loss: 0.1321 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 39/50
# 849/849 - 2s - loss: 0.0209 - accuracy: 0.0161 - val_loss: 0.0494 - val_accuracy: 2.9472e-04 - 2s/epoch - 2ms/step
# Epoch 40/50
# 849/849 - 2s - loss: 0.0211 - accuracy: 0.0098 - val_loss: 0.0521 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 41/50
# 849/849 - 2s - loss: 0.0208 - accuracy: 0.0192 - val_loss: 0.3248 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 42/50
# 849/849 - 2s - loss: 0.0200 - accuracy: 0.0292 - val_loss: 2.4046 - val_accuracy: 0.0027 - 2s/epoch - 2ms/step
# Epoch 43/50
# 849/849 - 2s - loss: 0.0206 - accuracy: 0.0151 - val_loss: 0.0344 - val_accuracy: 0.0024 - 2s/epoch - 2ms/step
# Epoch 44/50
# 849/849 - 2s - loss: 0.0202 - accuracy: 0.0198 - val_loss: 0.0875 - val_accuracy: 0.0430 - 2s/epoch - 2ms/step
# Epoch 45/50
# 849/849 - 2s - loss: 0.0204 - accuracy: 0.0259 - val_loss: 0.4912 - val_accuracy: 0.0085 - 2s/epoch - 2ms/step
# Epoch 46/50
# 849/849 - 2s - loss: 0.0201 - accuracy: 0.0220 - val_loss: 0.1236 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 47/50
# 849/849 - 2s - loss: 0.0202 - accuracy: 0.0306 - val_loss: 2.0588 - val_accuracy: 0.0103 - 2s/epoch - 2ms/step
# Epoch 48/50
# 849/849 - 2s - loss: 0.0202 - accuracy: 0.0287 - val_loss: 0.0506 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 49/50
# 849/849 - 2s - loss: 0.0204 - accuracy: 0.0332 - val_loss: 0.6429 - val_accuracy: 0.0000e+00 - 2s/epoch - 2ms/step
# Epoch 50/50
# 849/849 - 2s - loss: 0.0207 - accuracy: 0.0280 - val_loss: 1.6880 - val_accuracy: 0.0625 - 2s/epoch - 2ms/step

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
plt.plot(range(50), acc, label='Training Accuracy')
plt.plot(range(50), val_acc, label='Validation Accuracy')
plt.xlabel('Number of Epochs', fontsize=14, labelpad=20)
plt.ylabel('% Accuracy Value', fontsize=14, labelpad=20)
plt.legend(loc='lower right')
plt.title('Figure (a) Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(50), loss, label='Training Loss')
plt.plot(range(50), val_loss, label='Validation Loss')
plt.xlabel('Number of Epochs', fontsize=14, labelpad=20)
plt.ylabel('% Loss Value', fontsize=14, labelpad=20)
plt.legend(loc='upper right')
plt.title('Figure (b) Training and Validation Loss')
plt.show()

# define an encoder model (without the decoder)
encoder = Model(inputs=input_data_shape, outputs=bottleneck)
# save the encoder to file
encoder.save('encoder.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
#Building a Base Model to compare the performance after compressing the data using Encoder model.

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
t = MinMaxScaler()
t.fit(X_train)
X_train = t.transform(X_train)
X_test = t.transform(X_test)
# define model
model = RandomForestClassifier()
# fit model on training set
model.fit(X_train, y_train)
# make prediction on test set
yhat = model.predict(X_test)
# calculate accuracy
acc = accuracy_score(y_test, yhat)
print(acc)
# Out:
# 0.9776009431181845

# %%
#Compressing the input data using Encoder Model and fitting it on the Logistic Regression model.
# load the model from file
encoder = load_model('encoder.h5')

encoder.compile(optimizer='adam', loss='mse')

# encode the train data
X_train_encode = encoder.predict(X_train)

# encode the test data
X_test_encode = encoder.predict(X_test)

# nameOfHeaders = X_train.columns.values
# reduced_df = pd.DataFrame(encoder.predict(x_test), columns=nameOfHeaders)

# reduced_df.to_csv('PredictedJM1OnTestData.csv')


# define the model
random_forest = RandomForestClassifier(max_depth=50)
# fit the model on the training set
random_forest.fit(X_train_encode, y_train)
# make predictions on the test set
yhat = random_forest.predict(X_test_encode)
# calculate classification accuracy
acc = accuracy_score(y_test, yhat)
print(acc)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 425/425 [==============================] - 0s 892us/step
# 107/107 [==============================] - 0s 997us/step
# 0.9678750368405541

# %%
print('Optimal number of features: {}'.format(random_forest.n_features_))
# Out:
# Optimal number of features: 20
# C:\Users\Zbook\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\utils\deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
display(random_forest.feature_importances_)
plt.figure(figsize=(16, 9))
plt.title('Random Forest with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('% Correct Classification', fontsize=14, labelpad=20)
plt.plot(range(1, len(random_forest.feature_importances_) + 1), random_forest.feature_importances_, color='#303F9F', linewidth=3)

plt.show()
# Out:
# array([0.03286821, 0.05020756, 0.08035339, 0.05688659, 0.03660876,
#        0.05508153, 0.05626167, 0.04199297, 0.06327285, 0.04183605,
#        0.0488606 , 0.05263507, 0.04128202, 0.05086115, 0.03989397,
#        0.05993525, 0.03535515, 0.08374544, 0.02871776, 0.04334401])
